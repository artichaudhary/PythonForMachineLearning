# %% [markdown]
# installing Anaconda: if you get any installation issues, make sure you disable your antivirus and also install for 'just me'

# %% [markdown]
# in the next box, there is code to read the file

# %%
import numpy as np

# %%
import xlrd as xl
import xlrd
workbook = xl.open_workbook('C:/Users/Arti/Documents/Coursera/auto-mpg.xlsx')

# %%
import pandas as pd
import matplotlib.pyplot as mat
# %matplotlib inline 
auto= pd.read_csv('C:/Users/Arti/Documents/Coursera/auto-mpg.csv')

# %%
print(auto)
# Out:
#       mpg  Cylinders  displacement Horsepower  weight   acceleration  \
# 0    18.0          8         307.0        130     3504          12.0
# 1    15.0          8         350.0        165     3693          11.5
# 2    18.0          8         318.0        150     3436          11.0
# 3    16.0          8         304.0        150     3433          12.0
# 4    17.0          8         302.0        140     3449          10.5
# 5    15.0          8         429.0        198     4341          10.0
# 6    14.0          8         454.0        220     4354           9.0
# 7    14.0          8         440.0        215     4312           8.5
# 8    14.0          8         455.0        225     4425          10.0
# 9    15.0          8         390.0        190     3850           8.5
# 10   15.0          8         383.0        170     3563          10.0
# 11   14.0          8         340.0        160     3609           8.0
# 12   15.0          8         400.0        150     3761           9.5
# ...

# %%
print(workbook)

# %%
workbook1= pd.read_excel('C:/Users/Arti/Documents/Coursera/auto-mpg.xlsx')

# %%
print(workbook1)
# Out:
#       mpg  Cylinders  displacement Horsepower  weight   acceleration  \
# 0    18.0          8         307.0        130     3504          12.0
# 1    15.0          8         350.0        165     3693          11.5
# 2    18.0          8         318.0        150     3436          11.0
# 3    16.0          8         304.0        150     3433          12.0
# 4    17.0          8         302.0        140     3449          10.5
# 5    15.0          8         429.0        198     4341          10.0
# 6    14.0          8         454.0        220     4354           9.0
# 7    14.0          8         440.0        215     4312           8.5
# 8    14.0          8         455.0        225     4425          10.0
# 9    15.0          8         390.0        190     3850           8.5
# 10   15.0          8         383.0        170     3563          10.0
# 11   14.0          8         340.0        160     3609           8.0
# 12   15.0          8         400.0        150     3761           9.5
# ...

# %%
workbook1.describe()
# Out:
#               mpg   Cylinders  displacement      weight   acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      Origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
workbook1.fillna(0)
# Out:
#       mpg  Cylinders  displacement  Horsepower  weight   acceleration  \
# 0    18.0          8         307.0       130.0     3504          12.0
# 1    15.0          8         350.0       165.0     3693          11.5
# 2    18.0          8         318.0       150.0     3436          11.0
# 3    16.0          8         304.0       150.0     3433          12.0
# 4    17.0          8         302.0       140.0     3449          10.5
# 5    15.0          8         429.0       198.0     4341          10.0
# 6    14.0          8         454.0       220.0     4354           9.0
# 7    14.0          8         440.0       215.0     4312           8.5
# 8    14.0          8         455.0       225.0     4425          10.0
# 9    15.0          8         390.0       190.0     3850           8.5
# 10   15.0          8         383.0       170.0     3563          10.0
# 11   14.0          8         340.0       160.0     3609           8.0
# ...

# %%
workbook1.head
# Out:
# <bound method NDFrame.head of       mpg  Cylinders  displacement  Horsepower  weight   acceleration  \
# 0    18.0          8         307.0       130.0     3504          12.0
# 1    15.0          8         350.0       165.0     3693          11.5
# 2    18.0          8         318.0       150.0     3436          11.0
# 3    16.0          8         304.0       150.0     3433          12.0
# 4    17.0          8         302.0       140.0     3449          10.5
# 5    15.0          8         429.0       198.0     4341          10.0
# 6    14.0          8         454.0       220.0     4354           9.0
# 7    14.0          8         440.0       215.0     4312           8.5
# 8    14.0          8         455.0       225.0     4425          10.0
# 9    15.0          8         390.0       190.0     3850           8.5
# 10   15.0          8         383.0       170.0     3563          10.0
# 11   14.0          8         340.0       160.0     3609           8.0
# ...

# %%
print(workbook1.loc[:, 'mpg'])
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
# 5      15.0
# 6      14.0
# 7      14.0
# 8      14.0
# 9      15.0
# 10     15.0
# 11     14.0
# 12     15.0
# 13     14.0
# 14     24.0
# 15     22.0
# 16     18.0
# 17     21.0
# 18     27.0
# 19     26.0
# 20     25.0
# 21     24.0
# 22     25.0
# 23     26.0
# 24     21.0
# 25     10.0
# 26     10.0
# 27     11.0
# 28      9.0
# 29     27.0
#        ...
# 368    27.0
# 369    34.0
# 370    31.0
# 371    29.0
# 372    27.0
# 373    24.0
# 374    23.0
# 375    36.0
# 376    37.0
# 377    31.0
# 378    38.0
# 379    36.0
# 380    36.0
# 381    36.0
# 382    34.0
# 383    38.0
# 384    32.0
# 385    38.0
# 386    25.0
# 387    38.0
# 388    26.0
# 389    22.0
# 390    32.0
# 391    36.0
# 392    27.0
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
#print( workbook1.loc[:,'horsepower'])
list(workbook1)
# Out:
# ['mpg',
#  'Cylinders',
#  'displacement',
#  'Horsepower',
#  'weight ',
#  'acceleration',
#  'model year',
#  'Origin',
#  'Car Name']

# %%
mat.scatter( workbook1.loc[:, 'weight '], workbook1.loc[:, 'mpg'])

# %%
mat.show
# Out:
# <function matplotlib.pyplot.show>

# %%
mat.scatter( workbook1.loc[:, 'Cylinders'], workbook1.loc[:, 'mpg'])

# %%
mat.scatter( workbook1.loc[:, 'acceleration'], workbook1.loc[:, 'mpg'])

# %%
mat.scatter( workbook1.loc[:, 'model year'], workbook1.loc[:, 'mpg'])

# %%
mat.scatter( workbook1.loc[:, 'displacement'], workbook1.loc[:, 'mpg'])

# %%
mat.scatter( workbook1.loc[:, 'Origin'], workbook1.loc[:, 'mpg'])

# %%
workbook1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
# mpg             398 non-null float64
# Cylinders       398 non-null int64
# displacement    398 non-null float64
# Horsepower      392 non-null float64
# weight          398 non-null int64
# acceleration    398 non-null float64
# model year      398 non-null int64
# Origin          398 non-null int64
# Car Name        398 non-null object
# dtypes: float64(4), int64(4), object(1)
# memory usage: 28.1+ KB

# %%
workbook1['Horsepower'] = workbook1['Horsepower'].apply(pd.to_numeric, errors='coerce')

# %%
mat.scatter( workbook1.loc[:, 'Horsepower'], workbook1.loc[:, 'mpg'])

# %%
workbook1.keys()
# Out:
# Index(['mpg', 'Cylinders', 'displacement', 'Horsepower', 'weight ',
#        'acceleration', 'model year', 'Origin', 'Car Name'],
#       dtype='object')

# %%
from sklearn.linear_model import LinearRegression
workbook1= workbook1.dropna()
X = workbook1
X.columns= workbook1.columns
X = workbook1.drop('mpg', axis =1)

# %%
X= X.drop('Car Name', axis =1)
X= X.drop('Origin', axis =1)
#X=X.drop('model year', axis =1)
#X = X.drop('Horsepower', axis =1)

# %%
workbook1
# Out:
#       mpg  Cylinders  displacement  Horsepower  weight   acceleration  \
# 0    18.0          8         307.0       130.0     3504          12.0
# 1    15.0          8         350.0       165.0     3693          11.5
# 2    18.0          8         318.0       150.0     3436          11.0
# 3    16.0          8         304.0       150.0     3433          12.0
# 4    17.0          8         302.0       140.0     3449          10.5
# 5    15.0          8         429.0       198.0     4341          10.0
# 6    14.0          8         454.0       220.0     4354           9.0
# 7    14.0          8         440.0       215.0     4312           8.5
# 8    14.0          8         455.0       225.0     4425          10.0
# 9    15.0          8         390.0       190.0     3850           8.5
# 10   15.0          8         383.0       170.0     3563          10.0
# 11   14.0          8         340.0       160.0     3609           8.0
# ...

# %%
lm = LinearRegression()

# %%
y = workbook1['mpg']

# %%
lm.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print('estimated intercept', lm.intercept_)
# Out:
# estimated intercept -14.5352504805

# %%
print('no of coefficeints', len(lm.coef_))
# Out:
# no of coefficeints 6

# %%
print(lm.coef_)
# Out:
# [ -3.29859089e-01   7.67843024e-03  -3.91355574e-04  -6.79461791e-03
#    8.52732469e-02   7.53367180e-01]

# %%
lm.predict(X)
# Out:
# array([ 15.08291904,  14.07257469,  15.53631544,  15.53447451,
#         15.28640745,  10.13543367,  10.14518132,  10.2823774 ,
#          9.75375835,  13.04735326,  15.07939657,  14.27003871,
#         13.82978602,  18.85175174,  22.8737646 ,  19.77703076,
#         20.18480893,  21.5104138 ,  24.35531011,  26.88779881,
#         21.02865789,  22.39292633,  22.99745799,  23.65262179,
#         21.00103365,   8.07833662,   9.38643707,   9.29830867,
#          7.24571366,  25.10867729,  24.61286153,  24.52028351,
#         21.92845363,  16.61626354,  17.55758904,  17.74574   ,
#         17.69795664,  11.36255565,   9.96729942,  11.8765442 ,
#         11.97578129,   6.49865193,   8.09581057,   5.41677433,
#         19.93818121,  23.93993731,  17.83429946,  18.76798947,
#         24.64726853,  25.25871046,  25.78437479,  25.48591785,
#         27.72744749,  28.73542612,  27.51457176,  26.77034873,
#         25.06182966,  26.10937612,  25.80027716,  24.72889672,
# ...

# %%
msefull= np.mean((y-lm.predict(X))**2)

# %%
print (np.mean(msefull))
# Out:
# 11.5901709814

# %%
X.keys()
y.describe()
# Out:
# count    392.000000
# mean      23.445918
# std        7.805007
# min        9.000000
# 25%       17.000000
# 50%       22.750000
# 75%       29.000000
# max       46.600000
# Name: mpg, dtype: float64

# %%
lm.fit(X[['weight ']], y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
mseweight= np.mean((y-lm.predict(X[['weight ']]))**2)

# %%
print (np.mean(mseweight))
# Out:
# 18.6766165974

# %% [markdown]
# we observe an increase in Mean Squared Error

# %%
lm.fit(X[['displacement']], y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
msedisplacement= np.mean((y-lm.predict(X[['displacement']]))**2)

# %%
print (np.mean(msedisplacement))
# Out:
# 21.3745449401

# %% [markdown]
# Mena squared error with displacment is even more larger-- so not a good choice

# %%
lm.fit(X[['Cylinders']], y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
mseCylinders= np.mean((y-lm.predict(X[['Cylinders']]))**2)

# %%
print (np.mean(mseCylinders))
# Out:
# 24.0201795682

# %% [markdown]
# Mena squared error with Cylinders is even more larger-- so not a good choice

# %% [markdown]
# lm.fit(X[['model year']], y)

# %%
mseYear= np.mean((y-lm.predict(X[['model year']]))**2)

# %%
print (np.mean(mseYear))
# Out:
# 63287.2322152

# %% [markdown]
# Year is an even poor performer

# %%
lm.fit(X[['acceleration']], y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
mseacceleration= np.mean((y-lm.predict(X[['acceleration']]))**2)

# %%
print (np.mean(mseacceleration))
# Out:
# 49.8736273267

# %% [markdown]
# #acceleration

# %%
lm.fit(X[['Horsepower']], y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
mseHorsepower= np.mean((y-lm.predict(X[['Horsepower']]))**2)

# %%
print (np.mean(mseHorsepower))
# Out:
# 23.9436629386

# %%
from scipy.stats.stats import pearsonr

# %%
pearsonr(X[['displacement']], X[['weight ']])
# Out:
# (array([ 0.9329944]), array([  3.48908395e-175]))

# %% [markdown]
# looking at the high corelation between displacement and weight, it might make sense to drop displacement from the dataset as it seems to add no value and is a redundant variable

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state=42)

# %%
reg_all = LinearRegression()

# %%
# Fit the regressor to the training data
reg_all.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Predict on the test data: y_pred
y_pred = reg_all.predict(X_test)

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred, 'error': np.sqrt((y_test-y_pred)**2)})  
df
# Out:
#      Actual  Predicted     error
# 79     26.0  26.310510  0.310510
# 276    21.6  26.246675  4.646675
# 248    36.1  33.144880  2.955120
# 56     26.0  27.224405  1.224405
# 393    27.0  29.465502  2.465502
# 205    28.0  29.283892  1.283892
# 43     13.0   7.664045  5.335955
# 235    26.0  29.427010  3.427010
# 152    19.0  21.123174  2.123174
# 117    29.0  29.368582  0.368582
# 9      15.0  12.234700  2.765300
# 210    19.0  23.806551  4.806551
# 289    16.9  16.268749  0.631251
# 167    29.0  28.427192  0.572808
# 277    16.2  21.989568  5.789568
# 367    28.0  30.875595  2.875595
# 125    20.0  21.451296  1.451296
# 356    32.4  31.713602  0.686398
# 296    27.4  28.055904  0.655904
# 335    35.0  29.800987  5.199013
# 15     22.0  20.187371  1.812629
# 394    44.0  34.560368  9.439632
# 349    34.1  34.050610  0.049390
# 0      18.0  15.203197  2.796803
# 142    26.0  29.062198  3.062198
# 114    26.0  26.197334  0.197334
# 78     21.0  21.206620  0.206620
# ...

# %%
mat.scatter( df.loc[:, 'Actual'], df.loc[:, 'Predicted'])

# %%
X_test.describe()
# Out:
#         Cylinders  displacement  Horsepower      weight   acceleration  \
# count  118.000000    118.000000  118.000000   118.000000    118.000000
# mean     5.415254    188.995763  103.508475  2956.915254     15.585593
# std      1.686174    106.369749   39.454777   876.415208      2.525131
# min      3.000000     68.000000   46.000000  1760.000000      8.500000
# 25%      4.000000     98.000000   75.000000  2191.750000     14.200000
# 50%      4.000000    140.000000   93.500000  2792.500000     15.500000
# 75%      6.000000    256.000000  115.000000  3587.500000     16.675000
# max      8.000000    455.000000  225.000000  4951.000000     24.600000
#
#        model year
# count  118.000000
# mean    75.610169
# std      3.818609
# min     70.000000
# 25%     72.000000
# 50%     75.000000
# 75%     79.000000
# max     82.000000

# %%
# Compute and print R^2 and RMSE
print("R^2: {}".format(reg_all.score(X_test, y_test)))
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print("Root Mean Squared Error: {}".format(rmse))
# Out:
# R^2: 0.8076704419810161
# Root Mean Squared Error: 3.1898530578439

# %% [markdown]
# <B>from R-squared = Explained variation / Total variation</B>
#
# R-squared is always between 0 and 100%:
#
# 0% indicates that the model explains none of the variability of the response data around its mean.
# 100% indicates that the model explains all the variability of the response data around its mean.
# In general, the higher the R-squared, the better the model fits your data. However, there are important conditions for this guideline that I’ll talk about both in this post and my next post.
# R-squared = Explained variation / Total variation
#
# R-squared is always between 0 and 100%:
#
# 0% indicates that the model explains none of the variability of the response data around its mean.
# 100% indicates that the model explains all the variability of the response data around its mean.
# In general, the higher the R-squared, the better the model fits your data. However, there are important conditions for this guideline that I’ll talk about both in this post and my next post.

# %%
# Import the necessary modules for cross validation

from sklearn.model_selection import cross_val_score

# %%
# Create a linear regression object: reg
reg = LinearRegression()

# Compute 5-fold cross-validation scores: cv_scores
cv_scores = cross_val_score(reg, X, y, cv=3)

# Print the 5-fold cross-validation scores
print(cv_scores)
# Out:
# [ 0.26168833  0.77713041  0.42249634]

# %% [markdown]
# for cross validation, refer:
# https://www.kdnuggets.com/2018/01/training-test-sets-cross-validation.html?utm_content=buffer97fb3&utm_medium=social&utm_source=linkedin.com&utm_campaign=buffer

# %%
print(np.mean(cv_scores))
# Out:
# 0.487105027097

# %% [markdown]
# # Import necessary modules
# from sklearn.metrics import classification_report
# from sklearn.metrics import confusion_matrix
#
# # Create training and test set
# X_train, X_test, y_train, y_test = train_test_split(X,y, test_size =0.4, random_state = 42)
#
# # Instantiate a k-NN classifier: knn
# reg = LinearRegression()
#
# # Fit the classifier to the training data
# reg.fit(X_train, y_train)
#
# # Predict the labels of the test data: y_pred
# y_pred = reg.predict(X_test)
#
# # Generate the confusion matrix and classification report
# print(confusion_matrix(y_test, y_pred))
# print(classification_report(y_test, y_pred))
